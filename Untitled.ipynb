# %%
import sys
sys.path.append('./build')

# %%
import numpy as np

# %%
import ppf_registration_spatial_hashing as ppf

# %%
model = ppf.load_ply_file('./samples/data/parasaurolophus_6700.ply')
model

# %%
scene = ppf.load_ply_file('./samples/data/rs1_normals.ply')
scene

# %%
downsampled = ppf.random_downsample(model, 9.0)

# %%
from tpk4170.visualization import Viewer
from tpk4170.models import Grid

# %%
v = Viewer()
v.add(Grid())
# Out:
# Renderer(camera=PerspectiveCamera(aspect=1.5, children=(DirectionalLight(color='white', intensity=0.66, positi…

# %%
# !ls
# Out:
# CMakeLists.txt	 compute_normals.m			    run_jupyter.sh
# Dockerfile	 configure.sh				    samples
# LICENSE.txt	 example.cpython-36m-x86_64-linux-gnu.so    setup.py
# README.md	 include				    src
# Untitled.ipynb	 libalignment.so			    thesis.pdf
# build		 ppf_registration_spatial_hashing.egg-info
# build_docker.sh  run_docker.sh

# %%
downsampled.points
# Out:
# ...
# ...
# ...
#  ...]
